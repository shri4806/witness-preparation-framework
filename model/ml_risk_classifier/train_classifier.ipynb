# %% [markdown]
# # ML Risk Classifier — Training Notebook
#
# This notebook trains and evaluates a supervised machine learning
# classifier to estimate cross-examination risk in witness statements.
#
# Pipeline:
# 1. Load annotated dataset
# 2. Train-test split
# 3. TF-IDF feature extraction
# 4. Model training
# 5. Threshold tuning
# 6. Evaluation (Accuracy, Confusion Matrix, ROC)
